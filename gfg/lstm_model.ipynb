# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("AAPL.csv")
df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2013-01-02  19.779285  19.821428  19.343929  19.608213  16.769091
# 1  2013-01-03  19.567142  19.631071  19.321428  19.360714  16.557425
# 2  2013-01-04  19.177500  19.236786  18.779642  18.821428  16.096230
# 3  2013-01-07  18.642857  18.903570  18.400000  18.710714  16.001539
# 4  2013-01-08  18.900356  18.996071  18.616072  18.761070  16.044613
#
#       Volume
# 0  560518000
# 1  352965200
# 2  594333600
# 3  484156400
# 4  458707200

# %%
df = df.drop(["Date", "Adj Close"], axis = 1)
df.head()
# Out:
#         Open       High        Low      Close     Volume
# 0  19.779285  19.821428  19.343929  19.608213  560518000
# 1  19.567142  19.631071  19.321428  19.360714  352965200
# 2  19.177500  19.236786  18.779642  18.821428  594333600
# 3  18.642857  18.903570  18.400000  18.710714  484156400
# 4  18.900356  18.996071  18.616072  18.761070  458707200

# %%
plt.plot(df.Close)

# %%
df
# Out:
#             Open        High         Low       Close     Volume
# 0      19.779285   19.821428   19.343929   19.608213  560518000
# 1      19.567142   19.631071   19.321428   19.360714  352965200
# 2      19.177500   19.236786   18.779642   18.821428  594333600
# 3      18.642857   18.903570   18.400000   18.710714  484156400
# 4      18.900356   18.996071   18.616072   18.761070  458707200
# ...          ...         ...         ...         ...        ...
# 2740  189.889999  191.910004  189.880005  191.449997   46505100
# 2741  191.410004  191.520004  189.740005  190.639999   38134500
# 2742  191.490005  192.929993  190.830002  191.309998   39617700
# 2743  190.869995  190.899994  189.250000  189.970001   24048300
# 2744  189.919998  190.669998  188.899994  189.789993   40500500
#
# [2745 rows x 5 columns]

# %%
ma100 = df.Close.rolling(100).mean()
ma100
# Out:
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
#            ...
# 2740    181.619301
# 2741    181.586001
# 2742    181.574501
# 2743    181.560901
# 2744    181.540701
# Name: Close, Length: 2745, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100, "r")

# %%
ma200 = df.Close.rolling(200).mean()
ma200
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 2740    173.76660
# 2741    173.96115
# 2742    174.14445
# 2743    174.33470
# 2744    174.52930
# Name: Close, Length: 2745, dtype: float64

# %%
plt.figure(figsize=(12,6))
plt.plot(df.Close)
plt.plot(ma100, "r")
plt.plot(ma200, "g")

# %%
df.shape
# Out:
# (2745, 5)

# %%
# Splitting data into training and testing

data_train = pd.DataFrame(df["Close"][0:int(len(df)*0.70)])
data_test = pd.DataFrame(df["Close"][int(len(df)*0.70):int(len(df))])

print(data_train.shape)
print(data_test.shape)
# Out:
# (1921, 1)
# (824, 1)

# %%
data_train.head()
# Out:
#        Close
# 0  19.608213
# 1  19.360714
# 2  18.821428
# 3  18.710714
# 4  18.761070

# %%
data_test.head()
# Out:
#            Close
# 1921  115.707497
# 1922  118.275002
# 1923  124.370003
# 1924  125.857498
# 1925  124.824997

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))

# %%
data_train_array = scaler.fit_transform(data_train)

# %%
x_train = []
y_train = []
